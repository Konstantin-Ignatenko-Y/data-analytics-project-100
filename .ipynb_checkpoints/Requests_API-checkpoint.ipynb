# %% [markdown]
# ## Запросы к API

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import requests
import plotly.graph_objects as go
import plotly.express as px
from dotenv import load_dotenv

# %%
url_visits = "https://data-charts-api.hexlet.app/visits"
url_reg = "https://data-charts-api.hexlet.app/registrations"

params = {
    "begin": "2023-03-01",
    "end": "2023-09-01"
}

# %%
response_visits = requests.get(url_visits, params=params)
response_reg = requests.get(url_reg, params=params)

data_visits = response_visits.json()
data_reg = response_reg.json()
#print(data_visits[:2])

df_visits = pd.DataFrame(data_visits)
print(df_visits.head())

print('\n --- \n')

df_reg = pd.DataFrame(data_reg)
print(df_reg.head())

print('\n --- \n')

df_ads = pd.read_csv('./ads.csv') 
print(df_ads.head())
# Out:
#                                visit_id platform  \
# 0  60db9b85-12b3-447a-b93d-be177181f732      web
# 1  9e73a9ba-0c42-4a4d-bf8a-bde5bbe655ed      web
# 2  9e73a9ba-0c42-4a4d-bf8a-bde5bbe655ed      web
# 3  16dea4d8-2fb7-4c6b-b953-dc2b9686daf5      web
# 4  166bc823-c133-41fa-913d-3dbc495b2770      web
#
#                                           user_agent             datetime
# 0  Mozilla/5.0 (Windows NT 10.0; WOW64; Trident/7...  2023-04-05T15:03:40
# 1  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  2023-04-05T10:59:38
# 2  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  2023-04-03T14:53:40
# 3  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  2023-04-05T03:12:36
# 4  Mozilla/5.0 (Windows NT 10.0; WOW64; Trident/7...  2023-04-05T11:48:56
#
#  ---
#
#               datetime                               user_id  \
# 0  2023-03-01T07:40:13  2e0f6bb8-b029-4f45-a786-2b53990d37f1
# 1  2023-03-01T13:14:00  f007f97c-9d8b-48b5-af08-119bb8f6d9b6
# 2  2023-03-01T03:05:50  24ff46ae-32b3-4a74-8f27-7cf0b8f32f15
# 3  2023-03-01T00:04:47  3e9914e1-5d73-4c23-b25d-b59a3aeb2b60
# 4  2023-03-01T18:31:52  27f875fc-f8ce-4aeb-8722-0ecb283d0760
#
#                         email platform registration_type
# 0           ebyrd@example.org      web            google
# 1    knightgerald@example.org      web             email
# 2  cherylthompson@example.com      web             apple
# 3       halldavid@example.org      web             email
# 4        denise86@example.net      web            google
#
#  ---
#
#                   date utm_source utm_medium                utm_campaign  cost
# 0  2023-03-01T10:54:41     google        cpc  advanced_algorithms_series   212
# 1  2023-03-02T10:32:35     google        cpc  advanced_algorithms_series   252
# 2  2023-03-03T19:21:40     google        cpc  advanced_algorithms_series   202
# 3  2023-03-04T17:52:04     google        cpc  advanced_algorithms_series   223
# 4  2023-03-05T05:35:13     google        cpc  advanced_algorithms_series   265

# %%
# --- 2. Обработка визитов: оставляем только последний визит для каждого visit_id ---
# Сначала приводим datetime к типу datetime
df_visits['datetime'] = pd.to_datetime(df_visits['datetime'])

# Сортируем по дате, чтобы последний был в конце
df_visits_sorted = df_visits.sort_values('datetime')

# Оставляем только последний визит на visit_id
df_visits_unique = df_visits_sorted.drop_duplicates(subset='visit_id', keep='last')


# --- 3. Агрегация визитов по дате и платформе ---
# Создаём поле date_group как дату без времени (YYYY-MM-DD)
df_visits_unique['date_group'] = df_visits_unique['datetime'].dt.date

visits_agg = (
    df_visits_unique
    .groupby(['date_group', 'platform'], observed=True)
    .size()
    .reset_index(name='visits')
)


# --- 4. Агрегация регистраций по дате и платформе ---
df_reg['datetime'] = pd.to_datetime(df_reg['datetime'])
df_reg['date_group'] = df_reg['datetime'].dt.date

reg_agg = (
    df_reg
    .groupby(['date_group', 'platform'], observed=True)
    .size()
    .reset_index(name='registrations')
)


# --- 5. Объединение и расчёт конверсии ---
# Объединяем по date_group и platform (LEFT JOIN, чтобы не потерять дни без регистраций)
df_merged = visits_agg.merge(reg_agg, on=['date_group', 'platform'], how='left')

# Заполняем пропуски нулями (если визиты были, а регистраций нет)
df_merged['registrations'] = df_merged['registrations'].fillna(0).astype(int)

# Расчёт конверсии: registrations / visits. Если визитов 0 — конверсия 0
df_merged['conversion'] = (
    df_merged.apply(lambda row: row['registrations'] / row['visits'] if row['visits'] > 0 else 0, axis=1)
)

# Приводим date_group к строке, чтобы JSON был читаемым (дата как строка)
df_merged['date_group'] = df_merged['date_group'].astype(str)


# --- 6. Сохранение в conversion.json ---
df_merged.to_json('./conversion_dict.json', orient='records', force_ascii=False)

print(df_merged.head())
# Out:
#    date_group platform  visits  registrations  conversion
# 0  2023-03-01  android      75             61    0.813333
# 1  2023-03-01      ios      22             18    0.818182
# 2  2023-03-01      web     279              8    0.028674
# 3  2023-03-02  android      67             59    0.880597
# 4  2023-03-02      ios      31             24    0.774194
# C:\Users\ignatenko_ku\AppData\Local\Temp\ipykernel_24236\2947122943.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_visits_unique['date_group'] = df_visits_unique['datetime'].dt.date

# %%
# Обработка визитов: последний визит на visit_id
df_visits['datetime'] = pd.to_datetime(df_visits['datetime'])
df_visits_unique = (
    df_visits
    .sort_values('datetime')
    .drop_duplicates(subset='visit_id', keep='last')
    .copy()
)

# ИСПРАВЛЕНИЕ: группируем по дням, обнуляя время, но сохраняя тип datetime
df_visits_unique['date_group'] = df_visits_unique['datetime'].dt.normalize()

visits_agg = (
    df_visits_unique
    .groupby(['date_group', 'platform'], observed=True)
    .size()
    .reset_index(name='visits')
)

# Агрегация регистраций по дням и платформе
df_reg['datetime'] = pd.to_datetime(df_reg['datetime'])
# ИСПРАВЛЕНИЕ: тоже нормализуем, чтобы дни совпадали
df_reg['date_group'] = df_reg['datetime'].dt.normalize()

reg_agg = (
    df_reg
    .groupby(['date_group', 'platform'], observed=True)
    .size()
    .reset_index(name='registrations')
)

# Объединение и конверсия
df_merged = visits_agg.merge(reg_agg, on=['date_group', 'platform'], how='left')
df_merged['registrations'] = df_merged['registrations'].fillna(0).astype(int)

# Векторизованный расчёт конверсии (быстрее и чище, чем apply)
df_merged['conversion'] = df_merged['registrations'] / df_merged['visits']
df_merged['conversion'] = (df_merged['conversion'] * 100).fillna(0)

# Сохранение в JSON (timestamp-даты, orient=columns)
df_merged.to_json('./conversion.json', orient='columns', force_ascii=False)

print(df_merged[['date_group', 'platform', 'visits', 'registrations', 'conversion']].head(15))
# Out:
#    date_group platform  visits  registrations  conversion
# 0  2023-03-01  android      75             61   81.333333
# 1  2023-03-01      ios      22             18   81.818182
# 2  2023-03-01      web     279              8    2.867384
# 3  2023-03-02  android      67             59   88.059701
# 4  2023-03-02      ios      31             24   77.419355
# 5  2023-03-02      web     515             23    4.466019
# 6  2023-03-03  android      26             22   84.615385
# 7  2023-03-03      ios      40             34   85.000000
# 8  2023-03-03      web     617             51    8.265802
# 9  2023-03-04  android      94             77   81.914894
# 10 2023-03-04      bot     184              0    0.000000
# 11 2023-03-04      ios      68             43   63.235294
# 12 2023-03-04      web     485             39    8.041237
# 13 2023-03-05  android      66             54   81.818182
# 14 2023-03-05      bot     226              0    0.000000

# %%
# --- Подготовка рекламы (агрегация по дате) ---
df_ads['date'] = pd.to_datetime(df_ads['date'])
#df_ads['date_group'] = df_ads['date'].dt.date
# Делаем date_group как datetime (полночь дня) вместо date
df_ads['date_group'] = df_ads['date'].dt.normalize()  # это даст datetime64[ns], время = 00:00:00


ads_agg = (
    df_ads
    .groupby('date_group', observed=True)
    .agg(
        cost=('cost', 'sum'),
        utm_campaign=('utm_campaign', lambda x: x.iloc[0] if len(x) > 0 else 'none')
    )
    .reset_index()
)

ads_agg = ads_agg.sort_values('date_group')

# ---  Объединение с конверсиями ---
df_final = df_merged.merge(ads_agg, on='date_group', how='left')

# Заполняем отсутствующие значения (если в день не было рекламы)
df_final['cost'] = df_final['cost'].fillna(0)
df_final['utm_campaign'] = df_final['utm_campaign'].fillna('none')

# Сортировка: сначала по дате, потом по платформе
df_final = df_final.sort_values(['date_group', 'platform'])
print(df_final.head())

# --- Сохранение в JSON ---
df_final.to_json('./ads.json', orient='records', force_ascii=False)
# Out:
#   date_group platform  visits  registrations  conversion   cost  \
# 0 2023-03-01  android      75             61   81.333333  212.0
# 1 2023-03-01      ios      22             18   81.818182  212.0
# 2 2023-03-01      web     279              8    2.867384  212.0
# 3 2023-03-02  android      67             59   88.059701  252.0
# 4 2023-03-02      ios      31             24   77.419355  252.0
#
#                  utm_campaign
# 0  advanced_algorithms_series
# 1  advanced_algorithms_series
# 2  advanced_algorithms_series
# 3  advanced_algorithms_series
# 4  advanced_algorithms_series

# %% [markdown]
# ## Итоговые визиты (сумма по всем платформам)

# %%
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (10, 6)
plt.rcParams["font.size"] = 12

# --- Фильтрация по датам ---
start_date = '2023-03-01'
end_date = '2023-04-30'

df_period = df_final[(df_final['date_group'] >= start_date) & (df_final['date_group'] <= end_date)]

# Группируем по дате и суммируем визиты
visits_by_date = df_period.groupby('date_group')['visits'].sum()

# Строим график
plt.figure(figsize=(14, 6))
bars = plt.bar(visits_by_date.index, visits_by_date.values, color='#93c9df')

# Добавляем подписи над столбцами
plt.bar_label(bars, padding=3, fontsize=9, color='black', fmt='%d')

# Убираем вертикальные сетки
ax = plt.gca()
ax.grid(axis='y', linestyle='--', alpha=0.3)  # оставляем только горизонтальные (опционально)
ax.grid(axis='x', visible=False)              # отключаем вертикальные

# Настраиваем ось X: каждый день, без пропусков, наклон 45°
ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.xticks(rotation=45, ha='right')  # ha='right' — чтобы текст не «улетал» за край

plt.title("Total Visits")
plt.xlabel("Date")
plt.ylabel("visits")
#plt.xticks(rotation=45)
plt.tight_layout()

# Сохраняем и показываем
plt.savefig("./charts/total_visits.png", dpi=300)
plt.show()

# %% [markdown]
# ## Итоговые визиты с разбивкой по платформам (web, android, ios)

# %%
# Настройка стилей
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (14, 7)
plt.rcParams["font.size"] = 12

# Создаём папку (раскомментируй, если нужно)
#os.makedirs("./charts", exist_ok=True)

# --- 1. Фильтрация по периоду ---
start_date = '2023-03-01'
end_date = '2023-04-30'

# ВАЖНО: приводим date_group к datetime, если ещё не сделано
if not pd.api.types.is_datetime64_any_dtype(df_final['date_group']):
    df_final['date_group'] = pd.to_datetime(df_final['date_group'])

# Теперь фильтрация по датам будет работать корректно
df_filtered = df_final[
    (df_final['date_group'] >= start_date) &
    (df_final['date_group'] <= end_date)
].copy()

# --- 2. Фильтрация платформ ---
allowed_platforms = ['web', 'android', 'ios']
df_plot = df_filtered[df_filtered['platform'].isin(allowed_platforms)].copy()

# Агрегация: суммируем визиты по дате и платформе
visits_pivot = df_plot.pivot_table(
    index='date_group',
    columns='platform',
    values='visits',
    aggfunc='sum'
)

# Сортируем индекс (даты)
visits_pivot = visits_pivot.sort_index()

# --- 3. Построение столбчатой диаграммы ---
ax = visits_pivot.plot(
    kind='bar',
    stacked=True,
    figsize=(14, 7),
    width=0.8,
    edgecolor='black',
    linewidth=0.5
)

# Настраиваем ось X: только если индекс — это datetime
# (для bar-графика mdates не обязателен, но полезен, если хочешь именно даты)
# Для bar-графика лучше просто форматировать метки, а не ставить DayLocator
ax.set_xticklabels(
    [ts.strftime('%Y-%m-%d') for ts in visits_pivot.index],
    rotation=45,
    ha="right"
)

plt.title("Итоговые визиты с разбивкой по платформам (web, android, ios)", fontsize=14)
plt.xlabel("Дата", fontsize=12)
plt.ylabel("Визиты", fontsize=12)
plt.legend(title="Платформа", loc='upper right')
plt.tight_layout()

# Сохраняем график
plt.savefig("./charts/visits_by_platform_bar.png", dpi=300)
#print("График сохранён: ./charts/visits_by_platform_bar.png")
plt.show()

# %% [markdown]
# ## Итоговые регистрации (сумма по всем платформам)

# %%
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (14, 7)
plt.rcParams["font.size"] = 12

# --- Фильтрация по датам ---
start_date = '2023-03-01'
end_date = '2023-04-30'

df_period = df_final[(df_final['date_group'] >= start_date) & (df_final['date_group'] <= end_date)]

# Группируем по дате и суммируем регистрации
reg_by_date = df_period.groupby('date_group')['registrations'].sum()

# Строим график
plt.figure(figsize=(14, 6))
bars = plt.bar(reg_by_date.index, reg_by_date.values, color='#93c9df')

# Добавляем подписи над столбцами
plt.bar_label(bars, padding=3, fontsize=9, color='black', fmt='%d')

# Убираем вертикальные сетки
ax = plt.gca()
ax.grid(axis='y', linestyle='--', alpha=0.3)  # оставляем только горизонтальные (опционально)
ax.grid(axis='x', visible=False)              # отключаем вертикальные

# Настраиваем ось X: каждый день, без пропусков, наклон 45°
ax.xaxis.set_major_locator(mdates.DayLocator(interval=1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.xticks(rotation=45, ha='right')  # ha='right' — чтобы текст не «улетал» за край

plt.title("Total Weekly Registration")
plt.xlabel("Date")
plt.ylabel("Registrations")
#plt.xticks(rotation=45)
plt.tight_layout()

plt.savefig("./charts/total_weekly_registration.png", dpi=300)
plt.show()

# %% [markdown]
# ## Итоговые регистрации с разбивкой по платформе

# %%
# Сводная таблица
reg_by_platform = df_final.pivot_table(
    index='date_group',
    columns='platform',
    values='registrations',
    aggfunc='sum'
)

# --- 1. Приводим индекс к datetime (если ещё не datetime) ---
if not pd.api.types.is_datetime64_any_dtype(reg_by_platform.index):
    reg_by_platform.index = pd.to_datetime(reg_by_platform.index)

# --- 2. Фильтрация по периоду (через индекс) ---
start_date = '2023-03-01'
end_date = '2023-04-30'

mask = (reg_by_platform.index >= start_date) & (reg_by_platform.index <= end_date)
df_filtered = reg_by_platform.loc[mask].copy()

# --- 3. Фильтрация платформ (оставляем только нужные колонки) ---
allowed_platforms = ['web', 'android', 'ios']
# Оставляем только те колонки, которые есть в allowed_platforms И в датафрейме
cols_to_keep = [p for p in allowed_platforms if p in df_filtered.columns]
df_plot = df_filtered[cols_to_keep].copy()

# Построение столбчатой диаграммы с накоплением
ax = df_plot.plot(
    kind='bar',
    stacked=True,
    figsize=(12, 6),
    width=0.8
)

# Форматируем метки дат на оси X
ax.set_xticklabels(
    [ts.strftime('%Y-%m-%d') for ts in df_plot.index],
    rotation=45,
    ha="right"
)

plt.title("Регистрации по платформам (с накоплением)")
plt.xlabel("Дата")
plt.ylabel("Регистрации")

# Легенда справа
plt.legend(title="Платформа", loc='upper right')

plt.tight_layout()  # критично, чтобы легенда не обрезалась
plt.savefig("./charts/registrations_by_platform.png", dpi=300)
plt.show()

# %% [markdown]
# ## Итоговые конверсии

# %%
# 1. Исключаем платформу 'bot'
df_no_bot = df_merged[df_merged['platform'] != 'bot'].copy()

# 2. Агрегируем по дате
df_daily = (
    df_no_bot
    .groupby('date_group', as_index=False)[['visits', 'registrations']]
    .sum()
)

# Итоговая конверсия
df_daily['conversion_total'] = (df_daily['registrations'] / df_daily['visits']) * 100
df_daily['conversion_total'] = df_daily['conversion_total'].round(2)

# Приводим date_group к datetime ДО фильтрации
df_daily['date_group'] = pd.to_datetime(df_daily['date_group'])

# 3. Фильтруем по периоду
start_date = '2023-03-01'
end_date = '2023-04-30'
mask = (df_daily['date_group'] >= start_date) & (df_daily['date_group'] <= end_date)
df_plot = df_daily.loc[mask].copy()

# 4. Строим график и добавляем подписи
fig, ax = plt.subplots(figsize=(12, 6))

ax.plot(
    df_plot['date_group'],
    df_plot['conversion_total'],
    marker='o',
    linewidth=2,
    color='#2E86AB'
)

# Подписи над точками
for i, row in df_plot.iterrows():
    x_val = row['date_group']
    y_val = row['conversion_total']

    # Пропускаем битые значения
    if pd.isna(x_val) or pd.isna(y_val) or np.isinf(y_val):
        continue

    ax.annotate(
        f'{y_val:.1f}%',
        xy=(x_val, y_val),          # координаты точки
        xytext=(0, 8),              # сдвиг вверх на 8 пунктов
        textcoords='offset points',
        ha='center',
        va='bottom',
        fontsize=9,
        color='#2E86AB',
        weight='bold'
    )

ax.set_title('Итоговые конверсии по дням (без bot)', fontsize=14)
ax.set_xlabel('Дата', fontsize=12)
ax.set_ylabel('Конверсия, %', fontsize=12)
ax.grid(True, linestyle='--', alpha=0.3)
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("./charts/total_conversion", dpi=300)
plt.show()

# %% [markdown]
# ## Конверсия по каждой платформе

# %%
# --- Подготовка данных ---
# 1. Убираем bot, если он есть
df = df_final[df_final['platform'] != 'bot'].copy()

# 2. Приводим date_group к datetime
df['date_group'] = pd.to_datetime(df['date_group'])

# 3. Выбираем только нужные платформы
platforms = ['android', 'ios', 'web']
df_plot = df[df['platform'].isin(platforms)].copy()

# 4. Фильтруем по периоду (если нужно)
start_date = '2023-03-01'
end_date = '2023-04-30'
mask = (df_plot['date_group'] >= start_date) & (df_plot['date_group'] <= end_date)
df_plot = df_plot.loc[mask].copy()

if df_plot.empty:
    raise ValueError("Нет данных для выбранного диапазона дат.")

# --- Построение графиков ---
fig, ax = plt.subplots(figsize=(14, 7))

colors = {'android': '#2E86AB', 'ios': '#A23B72', 'web': '#F18F01'}
markers = {'android': 'o', 'ios': 's', 'web': '^'}

# Для подписей будем собирать все точки, чтобы не дублировать логику
all_annotations = []

for platform in platforms:
    sub = df_plot[df_plot['platform'] == platform].sort_values('date_group')
    
    if sub.empty:
        continue

    line = ax.plot(
        sub['date_group'],
        sub['conversion'],
        marker=markers[platform],
        linewidth=2,
        color=colors[platform],
        label=platform.capitalize(),
        markersize=6
    )[0]

    # Добавляем подписи процентов над каждой точкой
    for i, row in sub.iterrows():
        x_val = row['date_group']
        y_val = row['conversion']

        if pd.isna(x_val) or pd.isna(y_val) or np.isinf(y_val):
            continue

        ax.annotate(
            f'{y_val:.1f}%',
            xy=(x_val, y_val),
            xytext=(0, 8),          # сдвиг вверх на 8 пунктов
            textcoords='offset points',
            ha='center',
            va='bottom',
            fontsize=8,
            color=colors[platform],
            weight='bold'
        )

ax.set_title('Конверсии по платформам (android, ios, web)', fontsize=16)
ax.set_xlabel('Дата', fontsize=12)
ax.set_ylabel('Конверсия, %', fontsize=12)

ax.legend(title='Платформа', loc='best')
ax.grid(True, linestyle='--', alpha=0.3)

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# --- Подготовка данных ---
df = df_final.copy()

# 1. Убираем bot, если есть
df = df[df['platform'] != 'bot'].copy()

# 2. Приводим date_group к datetime
df['date_group'] = pd.to_datetime(df['date_group'])

# 3. Выбираем нужные платформы
platforms = ['android', 'ios', 'web']

# 4. Фильтруем по периоду
start_date = '2023-03-01'
end_date = '2023-04-30'
mask = (df['date_group'] >= start_date) & (df['date_group'] <= end_date)
df_plot = df.loc[mask].copy()

if df_plot.empty:
    raise ValueError("Нет данных для выбранного диапазона дат.")

# Цвета и маркеры для единообразия
colors = {'android': '#2E86AB', 'ios': '#A23B72', 'web': '#F18F01'}
markers = {'android': 'o', 'ios': 's', 'web': '^'}

# --- Строим отдельный график для каждой платформы ---
for platform in platforms:
    sub = df_plot[df_plot['platform'] == platform].sort_values('date_group')
    
    if sub.empty:
        print(f"Нет данных для платформы: {platform}")
        continue

    # Создаём отдельное окно для этой платформы
    plt.figure(figsize=(12, 6))
    
    plt.plot(
        sub['date_group'],
        sub['conversion'],
        marker=markers[platform],
        linewidth=2,
        color=colors[platform],
        label=platform.capitalize(),
        markersize=6
    )

    # Добавляем подписи процентов над каждой точкой
    for i, row in sub.iterrows():
        x_val = row['date_group']
        y_val = row['conversion']

        # Пропускаем битые значения
        if pd.isna(x_val) or pd.isna(y_val) or np.isinf(y_val):
            continue

        plt.annotate(
            f'{y_val:.1f}%',
            xy=(x_val, y_val),
            xytext=(0, 8),          # сдвиг вверх на 8 пунктов
            textcoords='offset points',
            ha='center',
            va='bottom',
            fontsize=9,
            color=colors[platform],
            weight='bold'
        )

    plt.title(f'Конверсия по платформе: {platform.upper()}', fontsize=16)
    plt.xlabel('Дата', fontsize=12)
    plt.ylabel('Конверсия, %', fontsize=12)
    plt.legend(loc='best')
    plt.grid(True, linestyle='--', alpha=0.3)
    plt.xticks(rotation=45)
    plt.tight_layout()
    
    # Показываем окно (именно это даёт отдельный график)
    plt.show()

# %%
# --- Подготовка данных ---
df = df_final.copy()

# Убираем bot, если есть
df = df[df['platform'] != 'bot'].copy()

# Приводим date_group к datetime
df['date_group'] = pd.to_datetime(df['date_group'])

# Выбираем нужные платформы
platforms = ['android', 'ios', 'web']

# Фильтруем по периоду
start_date = '2023-03-01'
end_date = '2023-04-30'
mask = (df['date_group'] >= start_date) & (df['date_group'] <= end_date)
df_plot = df.loc[mask].copy()

# Цвета и маркеры
colors = {'android': '#2E86AB', 'ios': '#A23B72', 'web': '#F18F01'}
markers = {'android': 'o', 'ios': 's', 'web': '^'}

# --- Создаём фигуру с 3 подграфиками (3 строки, 1 колонка) ---
fig, axes = plt.subplots(3, 1, figsize=(12, 14), sharex=True)  # sharex=True — общая ось X (даты)

for ax, platform in zip(axes, platforms):
    sub = df_plot[df_plot['platform'] == platform].sort_values('date_group')
    
    if sub.empty:
        ax.text(0.5, 0.5, f"Нет данных: {platform}", transform=ax.transAxes,
                ha='center', va='center', fontsize=12)
        ax.set_title(f'Конверсия: {platform.upper()}', fontsize=14)
        continue

    # Рисуем линию
    ax.plot(
        sub['date_group'],
        sub['conversion'],
        marker=markers[platform],
        linewidth=2,
        color=colors[platform],
        label=platform.capitalize(),
        markersize=6
    )

    # Подписи процентов над точками
    for i, row in sub.iterrows():
        x_val = row['date_group']
        y_val = row['conversion']

        if pd.isna(x_val) or pd.isna(y_val) or np.isinf(y_val):
            continue

        ax.annotate(
            f'{y_val:.1f}%',
            xy=(x_val, y_val),
            xytext=(0, 8),
            textcoords='offset points',
            ha='center',
            va='bottom',
            fontsize=9,
            color=colors[platform],
            weight='bold'
        )

    ax.set_title(f'Конверсия: {platform.upper()}', fontsize=14)
    ax.legend(loc='best')
    ax.grid(True, linestyle='--', alpha=0.3)

# Настройка общей оси X
plt.xticks(rotation=45)
fig.text(0.04, 0.5, 'Конверсия, %', va='center', rotation='vertical', fontsize=12)  # общая подпись оси Y
fig.suptitle('Конверсии по платформам (android, ios, web)', fontsize=16, y=0.995)

plt.tight_layout()

# --- Сохраняем всё в один файл ---
output_path = './charts/conversions_by_platform.png'
fig.savefig(output_path, dpi=300, bbox_inches='tight')

plt.show()

# %% [markdown]
# ## Средняя конверсия по всем платформам (по дням)

# %%
avg_conversion = df_final.groupby('date_group')['conversion'].mean()

plt.figure()
plt.plot(avg_conversion.index, avg_conversion.values, marker='d', color='purple')
plt.title("Средняя конверсия по дням")
plt.xlabel("Дата")
plt.ylabel("Средняя конверсия (%)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("./charts/avg_conversion.png", dpi=300)
plt.show()

# %% [markdown]
# ## Стоимости рекламы (cost) по дням

# %%
# --- Подготовка данных ---
df = df_final.copy()

# 1. Убираем bot
df = df[df['platform'] != 'bot'].copy()

# 2. Приводим date_group к datetime
df['date_group'] = pd.to_datetime(df['date_group'])

# 3. Фильтруем по периоду
start_date = '2023-03-01'
end_date = '2023-04-30'
mask = (df['date_group'] >= start_date) & (df['date_group'] <= end_date)
df_plot = df.loc[mask].copy()

# 4. Агрегируем стоимость по дате (суммируем cost по всем платформам за день)
cost_by_date = (
    df_plot
    .groupby('date_group', as_index=False)['cost']
    .sum()
    .sort_values('date_group')
)

# --- Построение графика ---
plt.figure(figsize=(12, 6))

plt.plot(
    cost_by_date['date_group'],
    cost_by_date['cost'],
    color='orange',
    linewidth=2,
    marker='o',
    markersize=6
)

# Добавляем подписи стоимости над точками
for i, row in cost_by_date.iterrows():
    x_val = row['date_group']
    y_val = row['cost']

    if pd.isna(x_val) or pd.isna(y_val) or np.isinf(y_val):
        continue

    plt.annotate(
        f'{y_val:.0f}',          # без дробной части (стоимость обычно целая)
        xy=(x_val, y_val),
        xytext=(0, 8),          # сдвиг вверх на 8 пунктов
        textcoords='offset points',
        ha='center',
        va='bottom',
        fontsize=9,
        color='darkorange',
        weight='bold'
    )

plt.title("Стоимость рекламы по дням", fontsize=14)
plt.xlabel("Дата", fontsize=12)
plt.ylabel("Стоимость", fontsize=12)
plt.grid(True, linestyle='--', alpha=0.3)
plt.xticks(rotation=45)
plt.tight_layout()

output_path = "./charts/ad_cost.png"
plt.savefig(output_path, dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Визиты за весь период с цветовым выделением рекламной кампании

# %%
plt.figure(figsize=(12, 6))
# Сортируем, чтобы порядок был предсказуемым
df_plot = df_final.sort_values('date_group')

scatter = plt.scatter(
    df_plot['date_group'],
    df_plot['visits'],
    c=df_plot['utm_campaign'].astype('category').cat.codes,  # кодируем кампании в цвета
    cmap='tab10',
    edgecolors='k',
    linewidth=0.5,
    alpha=0.8
)

# Добавляем легенду с названиями кампаний
handles, labels = scatter.legend_elements()
legend_labels = [
    df_plot['utm_campaign'].cat.categories[i] if i < len(df_plot['utm_campaign'].cat.categories) else 'none'
    for i in [int(h.get_label()) for h in handles]
]
# Но проще сделать легенду вручную по уникальным кампаниям
unique_campaigns = df_plot['utm_campaign'].unique()
colors = plt.get_cmap('tab10')(range(len(unique_campaigns)))

from matplotlib.patches import Patch
legend_handles = [Patch(color=colors[i], label=unique_campaigns[i]) for i in range(len(unique_campaigns))]
plt.legend(handles=legend_handles, title="Кампания")

plt.title("Визиты с выделением рекламных кампаний")
plt.xlabel("Дата")
plt.ylabel("Визиты")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("./charts/visits_with_campaign.png", dpi=300)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 19
#      15 # Добавляем легенду с названиями кампаний
#      16 handles, labels = scatter.legend_elements()
#      17 legend_labels = [
#      18     df_plot['utm_campaign'].cat.categories[i] if i < len(df_plot['utm_campaign'].cat.categories) else 'none'
# ---> 19     for i in [int(h.get_label()) for h in handles]
#      20 ]
#      21 # Но проще сделать легенду вручную по уникальным кампаниям
#      22 unique_campaigns = df_plot['utm_campaign'].unique()
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# ## Регистрации за весь период с цветовым выделением рекламной кампании

# %%
plt.figure(figsize=(12, 6))
df_plot = df_final.sort_values('date_group')

scatter = plt.scatter(
    df_plot['date_group'],
    df_plot['registrations'],
    c=df_plot['utm_campaign'].astype('category').cat.codes,
    cmap='tab10',
    edgecolors='k',
    linewidth=0.5,
    alpha=0.8
)

unique_campaigns = df_plot['utm_campaign'].unique()
colors = plt.get_cmap('tab10')(range(len(unique_campaigns)))
from matplotlib.patches import Patch
legend_handles = [Patch(color=colors[i], label=unique_campaigns[i]) for i in range(len(unique_campaigns))]
plt.legend(handles=legend_handles, title="Кампания")

plt.title("Регистрации с выделением рекламных кампаний")
plt.xlabel("Дата")
plt.ylabel("Регистрации")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("./charts/registrations_with_campaign.png", dpi=300)
plt.show()

# %% [markdown]
# ## Первая попытка уникальные визиты / пользователи

# %%
# --- Подготовка данных ---
df = df_final.copy()

# 1. Убираем bot
df = df[df['platform'] != 'bot'].copy()

# 2. Приводим date_group к datetime
df['date_group'] = pd.to_datetime(df['date_group'])

# 3. Фильтруем по периоду
start_date = '2023-03-01'
end_date = '2023-04-30'
mask = (df['date_group'] >= start_date) & (df['date_group'] <= end_date)
df_plot = df.loc[mask].copy()

if df_plot.empty:
    raise ValueError("Нет данных для выбранного диапазона дат.")

# --- Агрегация по дням: уникальные визиты и уникальные пользователи ---
# В твоём примере нет отдельного поля user_id, поэтому «уникальные пользователи»
# считаем как сумму registrations (если это подходит под задачу).
# Если у тебя есть user_id — замени aggregation ниже на nunique('user_id').

daily = (
    df_plot
    .groupby('date_group', as_index=False)
    .agg(
        visits_unique=('visits', 'sum'),          # если визиты уже уникальные — ок; если нет — уточни
        users_unique=('registrations', 'sum')      # здесь под «уникальными пользователями» берём registrations
    )
)

# Считаем средние за период
mean_visits = daily['visits_unique'].mean()
mean_users = daily['users_unique'].mean()

# --- Определение периодов рекламных кампаний ---
# У тебя в данных везде одна кампания advanced_algorithms_series.
# Ниже логика, которая автоматически находит все уникальные кампании и их периоды.
campaigns = df_plot['utm_campaign'].dropna().unique()

def get_campaign_periods(df, campaigns):
    periods = []
    for c in campaigns:
        sub = df[df['utm_campaign'] == c]
        if sub.empty:
            continue
        start = sub['date_group'].min()
        end = sub['date_group'].max()
        periods.append((c, start, end))
    return periods

campaign_periods = get_campaign_periods(df_plot, campaigns)

# Цвета для кампаний (можно расширить словарь)
camp_colors = {
    'advanced_algorithms_series': '#E1F5FE',
    # добавь другие кампании и цвета при необходимости
}

# --- Построение двух графиков в одном окне ---
fig, axes = plt.subplots(2, 1, figsize=(12, 10), sharex=True)  # 2 строки, 1 колонка, общая ось X

# График 1: Визиты
ax1 = axes[0]
ax1.plot(
    daily['date_group'],
    daily['visits_unique'],
    color='#2E86AB',
    linewidth=2,
    marker='o',
    markersize=4,
    label='Визиты (уникальные)'
)

# Линия среднего
ax1.axhline(mean_visits, color='red', linestyle='--', linewidth=1.5, label=f'Среднее: {mean_visits:.1f}')

# Цветовые фоны по кампаниям
for camp, start, end in campaign_periods:
    color = camp_colors.get(camp, '#F5F5F5')
    ax1.axvspan(start, end, color=color, alpha=0.3, label=camp if camp not in [p[0] for p in campaign_periods[:campaign_periods.index((camp,start,end))]] else "")

ax1.set_title('Уникальные визиты по дням с выделением рекламных кампаний', fontsize=14)
ax1.set_ylabel('Визиты', fontsize=12)
ax1.grid(True, linestyle=':', alpha=0.4)

# График 2: Пользователи
ax2 = axes[1]
ax2.plot(
    daily['date_group'],
    daily['users_unique'],
    color='#A23B72',
    linewidth=2,
    marker='s',
    markersize=4,
    label='Пользователи (уникальные)'
)

# Линия среднего
ax2.axhline(mean_users, color='red', linestyle='--', linewidth=1.5, label=f'Среднее: {mean_users:.1f}')

# Цветовые фоны по кампаниям (те же периоды)
for camp, start, end in campaign_periods:
    color = camp_colors.get(camp, '#F5F5F5')
    ax2.axvspan(start, end, color=color, alpha=0.3)

ax2.set_title('Уникальные пользователи по дням с выделением рекламных кампаний', fontsize=14)
ax2.set_xlabel('Дата', fontsize=12)
ax2.set_ylabel('Пользователи', fontsize=12)
ax2.grid(True, linestyle=':', alpha=0.4)

# Общая легенда (собираем все элементы)
# Чтобы не дублировать кампании в легенде, делаем её вручную для верхнего графика
handles1, labels1 = ax1.get_legend_handles_labels()
# Для нижнего графика берём только линию и среднее
handles2, labels2 = ax2.get_legend_handles_labels()

# Формируем единую легенду: линия визитов, линия пользователей, среднее (один раз), кампании
legend_handles = handles1[:2] + [handles2[0]] + [handles1[2]]  # визиты, среднее, пользователи, среднее (дубль уберём)
# Но проще собрать явно:
from matplotlib.lines import Line2D
from matplotlib.patches import Patch

legend_elements = [
    Line2D([0], [0], color='#2E86AB', lw=2, marker='o', label='Визиты (уникальные)'),
    Line2D([0], [0], color='#A23B72', lw=2, marker='s', label='Пользователи (уникальные)'),
    Line2D([0], [0], color='red', linestyle='--', lw=1.5, label='Среднее значение'),
]

# Добавляем элементы кампаний
for camp, _, _ in campaign_periods:
    color = camp_colors.get(camp, '#F5F5F5')
    legend_elements.append(Patch(facecolor=color, edgecolor='none', label=camp))

ax1.legend(handles=legend_elements, loc='upper left', fontsize=10)
# Убираем легенду со второго графика, чтобы не дублировалась
ax2.get_legend().remove()

plt.xticks(rotation=45)
plt.tight_layout()

output_path = "./charts/visits_users_campaigns.png"
#fig.savefig(output_path, dpi=300, bbox_inches='tight')
print(f"Графики сохранены в: {output_path}")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 138
#     136 ax1.legend(handles=legend_elements, loc='upper left', fontsize=10)
#     137 # Убираем легенду со второго графика, чтобы не дублировалась
# --> 138 ax2.get_legend().remove()
#     140 plt.xticks(rotation=45)
#     141 plt.tight_layout()
#
# AttributeError: 'NoneType' object has no attribute 'remove'

# %% [markdown]
# ## Вторая попытка уникальные визиты / пользователи

# %%
# --- Подготовка данных ---
df = df_final.copy()

# 1. Убираем bot
df = df[df['platform'] != 'bot'].copy()

# 2. Приводим date_group к datetime
df['date_group'] = pd.to_datetime(df['date_group'])

# 3. Фильтруем по периоду
start_date = '2023-03-01'
end_date = '2023-04-30'
mask = (df['date_group'] >= start_date) & (df['date_group'] <= end_date)
df_plot = df.loc[mask].copy()

if df_plot.empty:
    raise ValueError("Нет данных для выбранного диапазона дат.")

# --- Агрегация по дням ---
# Если у тебя есть user_id — замени registrations на user_id и используй nunique
daily = (
    df_plot
    .groupby('date_group', as_index=False)
    .agg(
        visits_unique=('visits', 'sum'),
        users_unique=('registrations', 'sum')
    )
)

mean_visits = daily['visits_unique'].mean()
mean_users = daily['users_unique'].mean()

# --- Периоды рекламных кампаний (только где utm_campaign не пустой) ---
# Группируем по кампании и находим min/max даты
campaign_periods = []
for camp, sub in df_plot.groupby('utm_campaign', dropna=True):
    start = sub['date_group'].min()
    end = sub['date_group'].max()
    campaign_periods.append((camp, start, end))

# Яркие цвета для кампаний (можно добавить больше при необходимости)
bright_colors = [
    '#FF5733',  # яркий оранжевый
    '#33FF57',  # ярко-зелёный
    '#3357FF',  # ярко‑синий
    '#F333FF',  # ярко‑пурпурный
    '#FFFF33'   # ярко‑жёлтый
]
camp_color_map = {camp: bright_colors[i % len(bright_colors)] for i, (camp, _, _) in enumerate(campaign_periods)}

# --- Построение двух графиков в одном окне ---
fig, axes = plt.subplots(2, 1, figsize=(12, 10), sharex=True)

# График 1: Визиты
ax1 = axes[0]

# Линия визитов
line_visits = ax1.plot(
    daily['date_group'],
    daily['visits_unique'],
    color='#2E86AB',
    linewidth=2,
    marker='o',
    markersize=4,
    label='Визиты (уникальные)'
)[0]

# Среднее
ax1.axhline(mean_visits, color='red', linestyle='--', linewidth=1.5, label=f'Среднее: {mean_visits:.1f}')

# Фон кампаний — только где есть кампания
for camp, start, end in campaign_periods:
    color = camp_color_map[camp]
    ax1.axvspan(start, end, color=color, alpha=0.25, label=camp)

ax1.set_title('Уникальные визиты по дням с выделением рекламных кампаний', fontsize=14)
ax1.set_ylabel('Визиты', fontsize=12)
ax1.grid(True, linestyle=':', alpha=0.4)

# Своя легенда для первого графика
ax1.legend(loc='upper left', fontsize=9, frameon=True)


# График 2: Пользователи
ax2 = axes[1]

# Линия пользователей
line_users = ax2.plot(
    daily['date_group'],
    daily['users_unique'],
    color='#A23B72',
    linewidth=2,
    marker='s',
    markersize=4,
    label='Пользователи (уникальные)'
)[0]

# Среднее
ax2.axhline(mean_users, color='red', linestyle='--', linewidth=1.5, label=f'Среднее: {mean_users:.1f}')

# Фон кампаний — те же периоды
for camp, start, end in campaign_periods:
    color = camp_color_map[camp]
    ax2.axvspan(start, end, color=color, alpha=0.25)  # без label, чтобы не дублировать в легенде

ax2.set_title('Уникальные пользователи по дням с выделением рекламных кампаний', fontsize=14)
ax2.set_xlabel('Дата', fontsize=12)
ax2.set_ylabel('Пользователи', fontsize=12)
ax2.grid(True, linestyle=':', alpha=0.4)

# Своя легенда для второго графика
# Добавляем элементы легенды вручную: линия, среднее, и по одному образцу каждой кампании
handles_users = [line_users]
labels_users = ['Пользователи (уникальные)']

handles_users.append(Line2D([0], [0], color='red', linestyle='--', lw=1.5, label=f'Среднее: {mean_users:.1f}'))

for camp, _, _ in campaign_periods:
    color = camp_color_map[camp]
    handles_users.append(Patch(facecolor=color, edgecolor='none', alpha=0.25, label=camp))

ax2.legend(handles=handles_users, loc='upper left', fontsize=9, frameon=True)

plt.xticks(rotation=45)
plt.tight_layout()

output_path = "./charts/visits_users_campaigns_two_legends.png"
#fig.savefig(output_path, dpi=300, bbox_inches='tight')
print(f"Графики сохранены в: {output_path}")

plt.show()
# Out:
# Графики сохранены в: ./charts/visits_users_campaigns_two_legends.png

# %%
# --- Подготовка данных ---
df = df_final.copy()

# 1. Убираем bot
df = df[df['platform'] != 'bot'].copy()

# 2. Приводим date_group к datetime
df['date_group'] = pd.to_datetime(df['date_group'])

# 3. Фильтруем по периоду
start_date = '2023-03-01'
end_date = '2023-04-30'
mask = (df['date_group'] >= start_date) & (df['date_group'] <= end_date)
df_plot = df.loc[mask].copy()

if df_plot.empty:
    raise ValueError("Нет данных для выбранного диапазона дат.")

# --- Агрегация по дням ---
daily = (
    df_plot
    .groupby('date_group', as_index=False)
    .agg(
        visits_unique=('visits', 'sum'),
        users_unique=('registrations', 'sum')
    )
)

mean_visits = daily['visits_unique'].mean()
mean_users = daily['users_unique'].mean()

# --- Периоды рекламных кампаний (только где utm_campaign не пустой) ---
campaign_periods = []
for camp, sub in df_plot.groupby('utm_campaign', dropna=True):
    start = sub['date_group'].min()
    end = sub['date_group'].max()
    campaign_periods.append((camp, start, end))

# Яркие цвета для кампаний
bright_colors = [
    '#FF5733',  # оранжевый
    '#33FF57',  # зелёный
    '#3357FF',  # синий
    '#F333FF',  # пурпурный
    '#FFFF33'   # жёлтый
]
camp_color_map = {camp: bright_colors[i % len(bright_colors)] for i, (camp, _, _) in enumerate(campaign_periods)}

# Цвет для «периода без рекламной компании» (серый, нейтральный)
no_camp_color = '#CCCCCC'

# --- Построение двух графиков в одном окне ---
fig, axes = plt.subplots(2, 1, figsize=(12, 10), sharex=True)

# === График 1: Визиты ===
ax1 = axes[0]

line_visits = ax1.plot(
    daily['date_group'],
    daily['visits_unique'],
    color='#2E86AB',
    linewidth=2,
    marker='o',
    markersize=4,
    label='Визиты (уникальные)'
)[0]

ax1.axhline(mean_visits, color='red', linestyle='--', linewidth=1.5, label=f'Среднее: {mean_visits:.1f}')

# Фон только для периодов с кампаниями
for camp, start, end in campaign_periods:
    color = camp_color_map[camp]
    ax1.axvspan(start, end, color=color, alpha=0.25, label=camp)

ax1.set_title('Уникальные визиты по дням с выделением рекламных кампаний', fontsize=14)
ax1.set_ylabel('Визиты', fontsize=12)
ax1.grid(True, linestyle=':', alpha=0.4)

# Легенда 1 (своя)
handles1 = [line_visits]
labels1 = ['Визиты (уникальные)']

handles1.append(Line2D([0], [0], color='red', linestyle='--', lw=1.5, label=f'Среднее: {mean_visits:.1f}'))

for camp, _, _ in campaign_periods:
    color = camp_color_map[camp]
    handles1.append(Patch(facecolor=color, edgecolor='none', alpha=0.25, label=camp))

# Добавляем элемент «период без рекламной компании»
handles1.append(Patch(facecolor=no_camp_color, edgecolor='none', alpha=0.25, label='Период без рекламной компании'))

ax1.legend(handles=handles1, loc='upper left', fontsize=9, frameon=True)


# === График 2: Пользователи ===
ax2 = axes[1]

line_users = ax2.plot(
    daily['date_group'],
    daily['users_unique'],
    color='#A23B72',
    linewidth=2,
    marker='s',
    markersize=4,
    label='Пользователи (уникальные)'
)[0]

ax2.axhline(mean_users, color='red', linestyle='--', linewidth=1.5, label=f'Среднее: {mean_users:.1f}')

# Фон кампаний (без label, чтобы не дублировать в легенде)
for camp, start, end in campaign_periods:
    color = camp_color_map[camp]
    ax2.axvspan(start, end, color=color, alpha=0.25)

ax2.set_title('Уникальные пользователи по дням с выделением рекламных кампаний', fontsize=14)
ax2.set_xlabel('Дата', fontsize=12)
ax2.set_ylabel('Пользователи', fontsize=12)
ax2.grid(True, linestyle=':', alpha=0.4)

# Легенда 2 (своя, с тем же элементом «без кампании»)
handles2 = [line_users]
labels2 = ['Пользователи (уникальные)']

handles2.append(Line2D([0], [0], color='red', linestyle='--', lw=1.5, label=f'Среднее: {mean_users:.1f}'))

# Кампании добавляем только как цветные блоки (без повторной отрисовки)
for camp, _, _ in campaign_periods:
    color = camp_color_map[camp]
    handles2.append(Patch(facecolor=color, edgecolor='none', alpha=0.25, label=camp))

# Добавляем элемент «период без рекламной компании»
handles2.append(Patch(facecolor=no_camp_color, edgecolor='none', alpha=0.25, label='Период без рекламной компании'))

ax2.legend(handles=handles2, loc='upper left', fontsize=9, frameon=True)

plt.xticks(rotation=45)
plt.tight_layout()

output_path = "./charts/visits_users_campaigns_with_no_camp_legend.png"
#fig.savefig(output_path, dpi=300, bbox_inches='tight')
print(f"Графики сохранены в: {output_path}")

plt.show()
# Out:
# Графики сохранены в: ./charts/visits_users_campaigns_with_no_camp_legend.png

# %%
# --- Подготовка данных ---
df = df_final.copy()

# 1. Убираем bot
df = df[df['platform'] != 'bot'].copy()

# 2. Приводим date_group к datetime
df['date_group'] = pd.to_datetime(df['date_group'])

# 3. Фильтруем по периоду
start_date = '2023-03-01'
end_date = '2023-04-30'
mask = (df['date_group'] >= start_date) & (df['date_group'] <= end_date)
df_plot = df.loc[mask].copy()

if df_plot.empty:
    raise ValueError("Нет данных для выбранного диапазона дат.")

# --- Агрегация по дням ---
daily = (
    df_plot
    .groupby('date_group', as_index=False)
    .agg(
        visits_unique=('visits', 'sum'),
        users_unique=('registrations', 'sum')
    )
)

mean_visits = daily['visits_unique'].mean()
mean_users = daily['users_unique'].mean()

# --- Периоды рекламных кампаний (только где utm_campaign не пустой и не None) ---
campaign_periods = []
for camp, sub in df_plot.groupby('utm_campaign', dropna=True):
    start = sub['date_group'].min()
    end = sub['date_group'].max()
    campaign_periods.append((camp, start, end))

# Яркие цвета для кампаний
bright_colors = [
    '#FF5733',  # оранжевый
    '#33FF57',  # зелёный
    '#3357FF',  # синий
    '#F333FF',  # пурпурный
    '#FFFF33'   # жёлтый
]
camp_color_map = {camp: bright_colors[i % len(bright_colors)] for i, (camp, _, _) in enumerate(campaign_periods)}

# --- Построение двух графиков в одном окне ---
fig, axes = plt.subplots(2, 1, figsize=(12, 10), sharex=True)

# === График 1: Визиты ===
ax1 = axes[0]

line_visits = ax1.plot(
    daily['date_group'],
    daily['visits_unique'],
    color='#2E86AB',
    linewidth=2,
    marker='o',
    markersize=4,
    label='Визиты (уникальные)'
)[0]

ax1.axhline(mean_visits, color='red', linestyle='--', linewidth=1.5, label=f'Среднее: {mean_visits:.1f}')

# Фон только для периодов с кампаниями
for camp, start, end in campaign_periods:
    color = camp_color_map[camp]
    ax1.axvspan(start, end, color=color, alpha=0.25, label=camp)

ax1.set_title('Уникальные визиты по дням с выделением рекламных кампаний', fontsize=14)
ax1.set_ylabel('Визиты', fontsize=12)
ax1.grid(True, linestyle=':', alpha=0.4)

# Легенда 1 (своя)
handles1 = [line_visits]
handles1.append(Line2D([0], [0], color='red', linestyle='--', lw=1.5, label=f'Среднее: {mean_visits:.1f}'))

for camp, _, _ in campaign_periods:
    color = camp_color_map[camp]
    handles1.append(Patch(facecolor=color, edgecolor='none', alpha=0.25, label=camp))

ax1.legend(handles=handles1, loc='upper left', fontsize=9, frameon=True)


# === График 2: Пользователи ===
ax2 = axes[1]

line_users = ax2.plot(
    daily['date_group'],
    daily['users_unique'],
    color='#A23B72',
    linewidth=2,
    marker='s',
    markersize=4,
    label='Пользователи (уникальные)'
)[0]

ax2.axhline(mean_users, color='red', linestyle='--', linewidth=1.5, label=f'Среднее: {mean_users:.1f}')

# Фон кампаний (без label, чтобы не дублировать в легенде)
for camp, start, end in campaign_periods:
    color = camp_color_map[camp]
    ax2.axvspan(start, end, color=color, alpha=0.25)

ax2.set_title('Уникальные пользователи по дням с выделением рекламных кампаний', fontsize=14)
ax2.set_xlabel('Дата', fontsize=12)
ax2.set_ylabel('Пользователи', fontsize=12)
ax2.grid(True, linestyle=':', alpha=0.4)

# Легенда 2 (своя): линия, среднее, и по одному образцу каждой кампании
handles2 = [line_users]
handles2.append(Line2D([0], [0], color='red', linestyle='--', lw=1.5, label=f'Среднее: {mean_users:.1f}'))

for camp, _, _ in campaign_periods:
    color = camp_color_map[camp]
    handles2.append(Patch(facecolor=color, edgecolor='none', alpha=0.25, label=camp))

ax2.legend(handles=handles2, loc='upper left', fontsize=9, frameon=True)

plt.xticks(rotation=45)
plt.tight_layout()

output_path = "./charts/visits_users_campaigns_clean.png"
#fig.savefig(output_path, dpi=300, bbox_inches='tight')
print(f"Графики сохранены в: {output_path}")

plt.show()
# Out:
# Графики сохранены в: ./charts/visits_users_campaigns_clean.png
